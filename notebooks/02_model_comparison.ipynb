# %% [markdown]
# # Model Comparison
#
# Minimal usage example for running the full four-model comparison and inspecting saved results.

# %%
from pathlib import Path
import pandas as pd

results_dir = Path('../results')
summary_path = results_dir / 'comparison_summary.csv'
summary = pd.read_csv(summary_path) if summary_path.exists() else None
summary

# %%
# Run this once from the repository root before reloading the summary:
# uv run python main.py

# %%
curve_path = results_dir / 'equity_curves' / 'xgboost_aggregated.csv'
curve = pd.read_csv(curve_path, parse_dates=['date']) if curve_path.exists() else None
curve.head() if curve is not None else None
